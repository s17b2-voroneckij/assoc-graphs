# %%
from quadrics import *
import scipy.stats as ss

# %%
eng_file = open('assoc_eng2.txt')
eng_graph, eng_dict = graph_from_file(eng_file)

# %%
our_eigenvalues = []
thresholds = [0, 0.001, 0.005, 0.01, 0.02, 0.05, 0.07, 0.09, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.93, 0.96, 1.0]
for threshold in thresholds:
    print(threshold)
    matr = eng_graph.laplace_matrix(min_weight=threshold)
    our_eigenvalues.append(eigenvalues(matr))
# Out:
# 0
# 0.001
# 0.005
# 0.01
# 0.02
# 0.05
# 0.07
# 0.09
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6
# 0.65
# 0.7
# 0.75
# 0.8
# 0.85
# 0.9
# 0.93
# 0.96
# 1.0

# %%
our_eigenvalues = list(map(lambda n: list(n), our_eigenvalues))
f = open('comp-spectr-eng.txt', 'w')
print(our_eigenvalues, file=f)
f.close()

# %%
from numpy import array, float16
f = open('comp-spectr-eng.txt')
our_eigenvalues = eval(f.read())

# %%
our_eigenvalues = list(map(lambda li: list(map(complex, li)), our_eigenvalues))
our_eigenvalues = list(map(lambda li: list(map(lambda x: x.real, li)), our_eigenvalues))

# %%
for elem1 in our_eigenvalues:
    for elem2 in our_eigenvalues:
        print(ss.wasserstein_distance(elem1, elem2), end=' ')
    print()
    print()
# Out:
# 0.0 0.0 0.0 0.0007969540944411213 8.76628811087268 18.218768667238493 20.068938024245867 21.238892196450486 21.63857339959673 22.971906738264394 23.67324166414226 24.117951764474057 24.423590337077304 24.629607473827452 24.794979061960554 24.910938416887827 25.020123513735804 25.10818886565053 25.166367785770074 25.225742163152024 25.27236499645348 25.30264991377565 25.324566630284917 25.34449091799163 25.35046820430365 25.352062147320186 25.353257604582584 25.35365609033672
#
# 0.0 0.0 0.0 0.0007969540944411213 8.76628811087268 18.218768667238493 20.068938024245867 21.238892196450486 21.63857339959673 22.971906738264394 23.67324166414226 24.117951764474057 24.423590337077304 24.629607473827452 24.794979061960554 24.910938416887827 25.020123513735804 25.10818886565053 25.166367785770074 25.225742163152024 25.27236499645348 25.30264991377565 25.324566630284917 25.34449091799163 25.35046820430365 25.352062147320186 25.353257604582584 25.35365609033672
#
# 0.0 0.0 0.0 0.0007969540944411213 8.76628811087268 18.218768667238493 20.068938024245867 21.238892196450486 21.63857339959673 22.971906738264394 23.67324166414226 24.117951764474057 24.423590337077304 24.629607473827452 24.794979061960554 24.910938416887827 25.020123513735804 25.10818886565053 25.166367785770074 25.225742163152024 25.27236499645348 25.30264991377565 25.324566630284917 25.34449091799163 25.35046820430365 25.352062147320186 25.353257604582584 25.35365609033672
#
# 0.0007969540944411213 0.0007969540944411213 0.0007969540944411213 0.0 8.76549115677824 18.21797171314405 20.068141070151427 21.238095242356046 21.63777644550229 22.97110978416995 23.672444710047817 24.117154810379617 24.42279338298286 24.628810519733012 24.794182107866114 24.910141462793383 25.019326559641364 25.107391911556086 25.16557083167563 25.22494520905758 25.271568042359036 25.301852959681213 25.32376967619048 25.343693963897188 25.349671250209205 25.351265193225743 25.352460650488148 25.35285913624228
#
# 25.35046820430365 25.35046820430365 25.35046820430365 25.349671250209205 16.584180093430966 7.131699537065154 5.281530180057782 4.111576007853159 3.7118948047069154 2.378561466039252 1.6772265401613877 1.232516439829588 0.9268778672263405 0.7208607304761911 0.5554891423430969 0.4395297874158199 0.33034469056784205 0.24227933865311846 0.18410041853357262 0.12472604115162389 0.0781032078501694 0.04781829052799355 0.025901574018728835 0.005977286312014441 0.0 0.001593943016537036 0.002789400278939924 0.003187886033074294
#
# 25.352062147320186 25.352062147320186 25.352062147320186 25.351265193225743 16.585774036447503 7.133293480081692 5.2831241230743196 4.113169950869697 3.7134887477234524 2.3801554090557895 1.6788204831779245 1.234110382846125 0.9284718102428775 0.7224546734927282 0.5570830853596338 0.4411237304323569 0.3319386335843791 0.24387328166965547 0.18569436155010963 0.1263199841681609 0.07969715086670642 0.04941223354453058 0.02749551703526587 0.0075712293285514765 0.001593943016537036 0.0 0.001195457262402888 0.0015939430165372581
#
# 25.353257604582584 25.353257604582584 25.353257604582584 25.352460650488148 16.586969493709905 7.134488937344094 5.284319580336722 4.1143654081321 3.7146842049858555 2.381350866318192 1.6800159404403274 1.235305840108528 0.9296672675052804 0.7236501307551311 0.5582785426220367 0.4423191876947598 0.33313409084678197 0.24506873893205836 0.18688981881251251 0.1275154414305638 0.0808926081291093 0.05060769080693347 0.02869097429766876 0.008766686590954365 0.002789400278939924 0.001195457262402888 0.0 0.00039848575413437004
#
# 25.35365609033672 25.35365609033672 25.35365609033672 25.35285913624228 16.58736797946404 7.134887423098228 5.284718066090856 4.114763893886234 3.71508269073999 2.3817493520723265 1.680414426194462 1.2357043258626623 0.9300657532594148 0.7240486165092654 0.5586770283761712 0.4427176734488942 0.3335325766009164 0.24546722468619278 0.18728830456664688 0.12791392718469813 0.08129109388324368 0.051006176561067845 0.02908946005180313 0.009165172345088735 0.003187886033074294 0.0015939430165372581 0.00039848575413437004 0.0

# %%
len(our_eigenvalues)
# Out:
# 28

# %%
import matplotlib.pyplot as plt

def plot(i, show=True):
    dists = [ss.wasserstein_distance(our_eigenvalues[i], our_eigenvalues[j]) for j in range(len(thresholds))]
    if show:
        plt.figure(figsize=(15, 15))
    plt.plot(thresholds, dists, label='threshold=' + str(thresholds[i]))
    plt.legend(loc='upper left')
    if show:
        plt.show()

    
#plot(0)

# %%
len(thresholds)
# Out:
# 28

# %%
for i in range(len(thresholds)):
    plot(i)

# %%
plt.figure(figsize=(15, 15))
for i in range(0, len(thresholds), 4):
    plot(i, show=False)
plt.show()

# %%
plt.figure(figsize=(15, 15))
for i in range(0, len(thresholds), 3):
    plot(i, show=False)
plt.show()

# %%
plt.figure(figsize=(15, 15))
for i in range(0, len(thresholds), 2):
    plot(i, show=False)
plt.show()

# %%
plt.figure(figsize=(15, 15))
for i in range(0, len(thresholds), 1):
    plot(i, show=False)
plt.show()

# %% [markdown]
# Теперь давайте попробуем посмотреть то же самое, но не для матрицы Лапласа, а для adjacency_matrix.

# %%
our_eigenvalues = []
thresholds = [0, 0.001, 0.005, 0.01, 0.02, 0.05, 0.07, 0.09, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.93, 0.96, 1.0]
for threshold in thresholds:
    print(threshold)
    matr = eng_graph.adjacency_matrix(min_weight=threshold)
    our_eigenvalues.append(eigenvalues(matr))
# Out:
# 0
# 0.001
# 0.005
# 0.01
# 0.02
# 0.05
# 0.07
# 0.09
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6
# 0.65
# 0.7
# 0.75
# 0.8
# 0.85
# 0.9
# 0.93
# 0.96
# 1.0

# %%
our_eigenvalues = list(map(lambda n: list(n), our_eigenvalues))
f = open('comp-spectr-eng-adjacency.txt', 'w')
print(our_eigenvalues, file=f)
f.close()

# %%
from numpy import array, float16
f = open('comp-spectr-eng-adjacency.txt')
our_eigenvalues = eval(f.read())

# %%
our_eigenvalues = list(map(lambda li: list(map(complex, li)), our_eigenvalues))
our_eigenvalues = list(map(lambda li: list(map(lambda x: x.real, li)), our_eigenvalues))

# %%
import matplotlib.pyplot as plt

def plot(i, show=True):
    dists = [ss.wasserstein_distance(our_eigenvalues[i], our_eigenvalues[j]) for j in range(len(thresholds))]
    plt.figure(figsize=(15, 15))
    plt.plot(thresholds, dists, label='threshold=' + str(thresholds[i]))
    plt.legend(loc='upper left')
    if show:
        plt.show()

    
#plot(0)

# %%
for i in range(len(thresholds)):
    plot(i)

# %%
plt.figure(figsize=(15, 15))
for i in range(0, len(thresholds), 4):
    plot(i, show=False)
plt.show()

# %%
plt.figure(figsize=(15, 15))
for i in range(0, len(thresholds), 1):
    plot(i, show=False)
plt.show()

# %% [markdown]
# Теперь посмотрим с матрицей инциндентности.

# %%
our_eigenvalues = []
thresholds = [0, 0.001, 0.005, 0.01, 0.02, 0.05, 0.07, 0.09, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.93, 0.96, 1.0]
for threshold in thresholds:
    print(threshold)
    matr = eng_graph.laplace_matrix(min_weight=threshold)
    matr = symm_mul_TA(matr)
    matr = symm_sum(matr)
    our_eigenvalues.append(eigenvalues(matr))
# Out:
# 0
# 0.001
# 0.005
# 0.01
# 0.02
# 0.05
# 0.07
# 0.09
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6
# 0.65
# 0.7
# 0.75
# 0.8
# 0.85
# 0.9
# 0.93
# 0.96
# 1.0

# %%
our_eigenvalues = list(map(lambda n: list(n), our_eigenvalues))
f = open('comp-spectr-eng-incidence-1.txt', 'w')
print(our_eigenvalues, file=f)
f.close()

# %%
from numpy import array, float16
f = open('comp-spectr-eng-incidence-1.txt')
our_eigenvalues = eval(f.read())

# %%
our_eigenvalues = list(map(lambda li: list(map(complex, li)), our_eigenvalues))
our_eigenvalues = list(map(lambda li: list(map(lambda x: x.real, li)), our_eigenvalues))

# %%
plt.figure(figsize=(15, 15))
for i in range(0, len(thresholds), 1):
    plot(i, show=False)
plt.show()

# %%
our_eigenvalues = []
thresholds = [0, 0.001, 0.005, 0.01, 0.02, 0.05, 0.07, 0.09, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.93, 0.96, 1.0]
for threshold in thresholds:
    print(threshold)
    matr = eng_graph.laplace_matrix(min_weight=threshold)
    matr = symm_mul_AT(matr)
    matr = symm_sum(matr)
    our_eigenvalues.append(eigenvalues(matr))
# Out:
# 0
# 0.001
# 0.005
# 0.01
# 0.02
# 0.05
# 0.07
# 0.09
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6
# 0.65
# 0.7
# 0.75
# 0.8
# 0.85
# 0.9
# 0.93
# 0.96
# 1.0

# %%
our_eigenvalues = list(map(lambda n: list(n), our_eigenvalues))
f = open('comp-spectr-eng-incidence-2.txt', 'w')
print(our_eigenvalues, file=f)
f.close()

# %%
from numpy import array, float16
f = open('comp-spectr-eng-incidence-2.txt')
our_eigenvalues = eval(f.read())
our_eigenvalues = list(map(lambda li: list(map(complex, li)), our_eigenvalues))
our_eigenvalues = list(map(lambda li: list(map(lambda x: x.real, li)), our_eigenvalues))

# %%
plt.figure(figsize=(15, 15))
for i in range(0, len(thresholds), 1):
    plot(i, show=False)
plt.show()
